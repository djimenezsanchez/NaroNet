# %% [markdown]
# ## Google Colab Hacks

# %%
# Stop Google Colab From Disconnecting
function KeepClicking(){
   console.log("Clicking");
   document.querySelector("colab-toolbar-button#connect").click()
}setInterval(KeepClicking,60000)
# Out:
#   File "<ipython-input-1-2db58996ae55>", line 2
#     function KeepClicking(){
#                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Set up Visual Studio Code Server

# %%
# !sudo apt-get install screen
# %pip install ray 
# %pip install XlsxWriter
# %pip install torch-scatter==latest+cu101 -f https://pytorch-geometric.com/whl/torch-1.6.0.html
# %pip install torch-sparse==latest+cu101 -f https://pytorch-geometric.com/whl/torch-1.6.0.html
# %pip install torch-cluster==latest+cu101 -f https://pytorch-geometric.com/whl/torch-1.6.0.html
# %pip install torch-spline-conv==latest+cu101 -f https://pytorch-geometric.com/whl/torch-1.6.0.html
# %pip install torch-geometric
# %pip install pycox
# %pip install torchviz
# %pip install adabound

from google.colab import drive

drive.mount('/content/drive', force_remount=False)
# %cd /content/drive/My\ Drive/Naro_Classification/codes/

import main_v3
main_v3.run()
from main_v3 import run
run()

# %pip install colabcode
from colabcode import ColabCode
ColabCode(port=10100)
print('/content/drive/My Drive/Naro_Classification/colabcodes/')
