# %%
function KeepClicking(){
   console.log("Clicking");
   document.querySelector("colab-toolbar-button#connect").click()
}setInterval(KeepClicking,60000)

# %% [markdown]
# # Initialize google colab

# %%
# %pip install ray 
# %pip install XlsxWriter
# %pip install torch-scatter==latest+cu101 -f https://pytorch-geometric.com/whl/torch-1.6.0.html
# %pip install torch-sparse==latest+cu101 -f https://pytorch-geometric.com/whl/torch-1.6.0.html
# %pip install torch-cluster==latest+cu101 -f https://pytorch-geometric.com/whl/torch-1.6.0.html
# %pip install torch-spline-conv==latest+cu101 -f https://pytorch-geometric.com/whl/torch-1.6.0.html
# %pip install torch-geometric
# %pip install pycox
# %pip install torchviz
# %pip install adabound
# %pip install statannot
# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)

# %% [markdown]
# # Connect to your Google Drive account

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True) # Google drive will ask you to give access to your drive account
# %cd /content/drive/My\ Drive/Naro_Classification/codes_v4
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Naro_Classification/codes_v4

# %% [markdown]
# # Run experiment on the specified path

# %%
path = "/content/drive/My Drive/Naro_Classification/Images-Endometrial_LowGrade_GPUSERVER/" 
import main_v4
# %tb
main_v4.run(path)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning:
#
# The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning:
#
# The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#
# No traceback available to show.
# ...
